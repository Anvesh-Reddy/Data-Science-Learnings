# %%
from tpot import TPOTClassifier, TPOTRegressor
from sklearn.datasets import load_digits, load_boston
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Classification

# %%
digits = load_digits()
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target)

# %%
tpot_obj_clf = TPOTClassifier(generations=5, population_size=20, verbosity=2)
tpot_obj_clf.fit(X_train, y_train)
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9717352980942765
# Generation 2 - Current best internal CV score: 0.9717352980942765
# Generation 3 - Current best internal CV score: 0.9836468891178232
# Generation 4 - Current best internal CV score: 0.9836468891178232
# Generation 5 - Current best internal CV score: 0.9836468891178232
#
# Best pipeline: LogisticRegression(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), C=20.0, dual=True, penalty=l2)
# TPOTClassifier(config_dict=None, crossover_rate=0.1, cv=5,
#                disable_update_check=False, early_stop=None, generations=5,
#                max_eval_time_mins=5, max_time_mins=None, memory=None,
#                mutation_rate=0.9, n_jobs=1, offspring_size=None,
#                periodic_checkpoint_folder=None, population_size=20,
#                random_state=None, scoring=None, subsample=1.0, template=None,
#                use_dask=False, verbosity=2, warm_start=False)

# %%
tpot_obj_clf.score(X_test, y_test)
# Out:
# 0.9888888888888889

# %%
tpot_obj_clf.fitted_pipeline_
# Out:
# Pipeline(memory=None,
#          steps=[('polynomialfeatures',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('logisticregression',
#                  LogisticRegression(C=20.0, class_weight=None, dual=True,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='warn', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
tpot_obj_clf.evaluated_individuals_
# Out:
# {'GaussianNB(input_matrix)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.8382029071905859},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.5, ExtraTreesClassifier__min_samples_leaf=7, ExtraTreesClassifier__min_samples_split=12, ExtraTreesClassifier__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': 0.9473061435448089},
#  'DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=13, DecisionTreeClassifier__min_samples_split=9)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
# ...

# %%
tpot_obj_clf.export('tpot_digits_pipeline.py')

# %% [markdown]
# ### Regression

# %%
boston = load_boston()
X_train_boston, X_test_boston, y_train_boston, y_test_boston = train_test_split(boston.data, boston.target)

# %%
tpot_obj_rgr = TPOTRegressor(template='Selector-Transformer-Regressor', generations=5, population_size=20, verbosity=2)
tpot_obj_rgr.fit(X_train_boston, y_train_boston)
# Out:
# ...
# Generation 1 - Current best internal CV score: -14.150439548807622
# Generation 2 - Current best internal CV score: -13.19399075701017
# Generation 3 - Current best internal CV score: -13.19399075701017
# Generation 4 - Current best internal CV score: -13.19399075701017
# Generation 5 - Current best internal CV score: -13.19399075701017
#
# Best pipeline: RandomForestRegressor(PolynomialFeatures(VarianceThreshold(input_matrix, threshold=0.001), degree=2, include_bias=False, interaction_only=False), bootstrap=False, max_features=0.15000000000000002, min_samples_leaf=5, min_samples_split=3, n_estimators=100)
# TPOTRegressor(config_dict=None, crossover_rate=0.1, cv=5,
#               disable_update_check=False, early_stop=None, generations=5,
#               max_eval_time_mins=5, max_time_mins=None, memory=None,
#               mutation_rate=0.9, n_jobs=1, offspring_size=None,
#               periodic_checkpoint_folder=None, population_size=20,
# ...

# %%
tpot_obj_rgr_specific = TPOTRegressor(template='StandardScaler-OneHotEncoder-Regressor', generations=5, population_size=20, verbosity=2)
tpot_obj_rgr_specific.fit(X_train_boston, y_train_boston)
# Out:
# ...
# Generation 1 - Current best internal CV score: -11.845396760584226
# Generation 2 - Current best internal CV score: -11.845396760584226
# Generation 3 - Current best internal CV score: -11.845396760584226
# Generation 4 - Current best internal CV score: -10.01147965199888
# Generation 5 - Current best internal CV score: -10.01147965199888
#
# Best pipeline: XGBRegressor(OneHotEncoder(StandardScaler(input_matrix), minimum_fraction=0.25, sparse=False, threshold=10), learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100, nthread=1, objective=reg:squarederror, subsample=0.9500000000000001)
# TPOTRegressor(config_dict=None, crossover_rate=0.1, cv=5,
#               disable_update_check=False, early_stop=None, generations=5,
#               max_eval_time_mins=5, max_time_mins=None, memory=None,
#               mutation_rate=0.9, n_jobs=1, offspring_size=None,
#               periodic_checkpoint_folder=None, population_size=20,
# ...

# %%
tpot_obj_rgr.score(X_test_boston, y_test_boston)
# Out:
# -10.609258730331556

# %%
tpot_obj_rgr.fitted_pipeline_
# Out:
# Pipeline(memory=None,
#          steps=[('variancethreshold', VarianceThreshold(threshold=0.001)),
#                 ('polynomialfeatures',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('randomforestregressor',
#                  RandomForestRegressor(bootstrap=False, criterion='mse',
#                                        max_depth=None,
#                                        max_features=0.15000000000000002,
#                                        max_leaf_nodes=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=5, min_samples_split=3,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=None,
# ...

# %%
tpot_obj_rgr.evaluated_individuals_
# Out:
# {'XGBRegressor(Binarizer(SelectPercentile(input_matrix, SelectPercentile__percentile=80), Binarizer__threshold=0.25), XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=9, XGBRegressor__min_child_weight=19, XGBRegressor__n_estimators=100, XGBRegressor__nthread=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.9000000000000001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 3,
#   'internal_cv_score': -75.28220291844919},
#  'KNeighborsRegressor(ZeroCount(SelectFwe(input_matrix, SelectFwe__alpha=0.007)), KNeighborsRegressor__n_neighbors=42, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 3,
#   'internal_cv_score': -62.09333590404583},
# ...

# %% [markdown]
# ### TPOT using Config file

# %%
import json

# %%
with open('tpot_digits_config.py', 'r') as f:
    tpot_config = json.loads(f.read())

# %%
tpot = TPOTClassifier(generations=5, population_size=20, verbosity=2,
                      config_dict=tpot_config)
tpot.fit(X_train, y_train)
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.982878101628043
# Generation 2 - Current best internal CV score: 0.982878101628043
# Generation 3 - Current best internal CV score: 0.982878101628043
# Generation 4 - Current best internal CV score: 0.982878101628043
# Generation 5 - Current best internal CV score: 0.982878101628043
#
# Best pipeline: KNeighborsClassifier(input_matrix, algorithm=auto, leaf_size=30, metric=minkowski, metric_params=None, n_jobs=1, n_neighbors=2, p=2, weights=distance)
# TPOTClassifier(config_dict={'sklearn.decomposition.pca.PCA': {'copy': [True],
#                                                               'iterated_power': [4],
#                                                               'n_components': [None],
#                                                               'random_state': [None],
#                                                               'svd_solver': ['randomized'],
# ...

# %%
tpot.score(X_test, y_test)
# Out:
# 0.9888888888888889
